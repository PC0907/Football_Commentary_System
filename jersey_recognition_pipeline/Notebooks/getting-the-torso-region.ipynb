# %%
pip install mmcv==2.1.0 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.4/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.4/index.html
# Collecting mmcv==2.1.0
#   Using cached mmcv-2.1.0.tar.gz (471 kB)
#   Preparing metadata (setup.py) ... done
# Collecting addict (from mmcv==2.1.0)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.1.0)
#   Using cached mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (11.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv==2.1.0) (6.0.2)
# Collecting yapf (from mmcv==2.1.0)
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.7.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.9.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (2.5.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (4.10.0.84)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->mmcv==2.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->mmcv==2.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->mmcv==2.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->mmcv==2.1.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->mmcv==2.1.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->mmcv==2.1.0) (2.4.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv==2.1.0) (4.3.6)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv==2.1.0) (2.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->mmcv==2.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->mmcv==2.1.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->mmcv==2.1.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->mmcv==2.1.0) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (4.12.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->mmcv==2.1.0) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.17.0)
# Using cached mmengine-0.10.7-py3-none-any.whl (452 kB)
# Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Using cached yapf-0.43.0-py3-none-any.whl (256 kB)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (setup.py) ... done
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp310-cp310-linux_x86_64.whl size=39182576 sha256=0e32205fac2a6b2bd63b160c3b22612dbf9170760d0a0a8eb95eb022669e71bd
#   Stored in directory: /root/.cache/pip/wheels/8b/09/35/94a7f7ba6a00e3810abd0492340e4cbba0ff3d443120a94120
# Successfully built mmcv
# Installing collected packages: addict, yapf, mmengine, mmcv
# Successfully installed addict-2.4.0 mmcv-2.1.0 mmengine-0.10.7 yapf-0.43.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install "mmdet>=3.0.0"  # Latest 3.x version
# !pip install "mmpose>=1.2.0"  # Latest 1.x version
# Out:
# Collecting mmdet>=3.0.0
#   Downloading mmdet-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (3.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (1.26.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (2.0.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (1.13.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (2.0.7)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (1.17.0)
# Collecting terminaltables (from mmdet>=3.0.0)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->mmdet>=3.0.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->mmdet>=3.0.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->mmdet>=3.0.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->mmdet>=3.0.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->mmdet>=3.0.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->mmdet>=3.0.0) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->mmdet>=3.0.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->mmdet>=3.0.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->mmdet>=3.0.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->mmdet>=3.0.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->mmdet>=3.0.0) (2024.2.0)
# Downloading mmdet-3.3.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.7 MB/s eta 0:00:0000:01
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, mmdet
# Successfully installed mmdet-3.3.0 terminaltables-3.1.10
# Collecting mmpose>=1.2.0
#   Downloading mmpose-1.3.2-py2.py3-none-any.whl.metadata (29 kB)
# Collecting chumpy (from mmpose>=1.2.0)
#   Downloading chumpy-0.70.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting json-tricks (from mmpose>=1.2.0)
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmpose>=1.2.0) (3.7.5)
# Collecting munkres (from mmpose>=1.2.0)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl.metadata (980 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmpose>=1.2.0) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from mmpose>=1.2.0) (4.10.0.84)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from mmpose>=1.2.0) (11.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmpose>=1.2.0) (1.13.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from mmpose>=1.2.0) (0.20.1+cu121)
# Collecting xtcocotools>=1.12 (from mmpose>=1.2.0)
#   Downloading xtcocotools-1.14.3-cp310-cp310-manylinux1_x86_64.whl.metadata (364 bytes)
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.10/dist-packages (from xtcocotools>=1.12->mmpose>=1.2.0) (75.1.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.10/dist-packages (from xtcocotools>=1.12->mmpose>=1.2.0) (3.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmpose>=1.2.0) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->mmpose>=1.2.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->mmpose>=1.2.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->mmpose>=1.2.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->mmpose>=1.2.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->mmpose>=1.2.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->mmpose>=1.2.0) (2.4.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from chumpy->mmpose>=1.2.0) (1.17.0)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchvision->mmpose>=1.2.0) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision->mmpose>=1.2.0) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision->mmpose>=1.2.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision->mmpose>=1.2.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision->mmpose>=1.2.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision->mmpose>=1.2.0) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision->mmpose>=1.2.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision->mmpose>=1.2.0) (1.3.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->mmpose>=1.2.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->mmpose>=1.2.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->mmpose>=1.2.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->mmpose>=1.2.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->mmpose>=1.2.0) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchvision->mmpose>=1.2.0) (3.0.2)
# Downloading mmpose-1.3.2-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.6 MB/s eta 0:00:0000:01
# Downloading xtcocotools-1.14.3-cp310-cp310-manylinux1_x86_64.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.0/436.0 kB 26.2 MB/s eta 0:00:00
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Building wheels for collected packages: chumpy
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.70-py3-none-any.whl size=58264 sha256=0e86b439da8c03b72d6f3fb6f96dac97dd42393ee9eba51c076ebfbcfb6af464
#   Stored in directory: /root/.cache/pip/wheels/e0/c1/ef/29ba7be03653a29ef6f2c3e1956d6c4d8877f2b243af411db1
# Successfully built chumpy
# Installing collected packages: munkres, json-tricks, xtcocotools, chumpy, mmpose
# Successfully installed chumpy-0.70 json-tricks-3.17.3 mmpose-1.3.2 munkres-1.1.4 xtcocotools-1.14.3

# %%
try:
    import mmcv
    print("MMCV version:", mmcv.__version__)

    import mmengine
    print("MMEngine version:", mmengine.__version__)

    import mmdet
    print("MMDet version:", mmdet.__version__)

    import mmpose
    print("MMPose version:", mmpose.__version__)

    print("\nAll required packages installed successfully!")
except ImportError as e:
    print("Error:", e)
# Out:
# MMCV version: 2.1.0
# MMEngine version: 0.10.7
# MMDet version: 3.3.0
# MMPose version: 1.3.2
#
# All required packages installed successfully!

# %%
# !git clone https://github.com/ViTAE-Transformer/ViTPose
# Out:
# Cloning into 'ViTPose'...
# remote: Enumerating objects: 1859, done.
# remote: Counting objects: 100% (1041/1041), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 1859 (delta 794), reused 725 (delta 725), pack-reused 818 (from 1)
# Receiving objects: 100% (1859/1859), 10.75 MiB | 38.88 MiB/s, done.
# Resolving deltas: 100% (958/958), done.

# %%
from mmpose.apis import init_model, inference_topdown
from mmpose.utils import register_all_modules

# Verify PyTorch CUDA setup
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# Print MM* versions
import mmcv
import mmengine
import mmdet
import mmpose

print("\nInstalled versions:")
print(f"MMCV version: {mmcv.__version__}")
print(f"MMEngine version: {mmengine.__version__}")
print(f"MMDet version: {mmdet.__version__}")
print(f"MMPose version: {mmpose.__version__}")

# Try to register modules
register_all_modules()
# Out:
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# CUDA version: 12.1
#
# Installed versions:
# MMCV version: 2.1.0
# MMEngine version: 0.10.7
# MMDet version: 3.3.0
# MMPose version: 1.3.2

# %%
import os
import gdown

# Create checkpoints directory
os.makedirs('./ViTPose/checkpoints', exist_ok=True)

# Download ViTPose-H model
model_url = 'https://drive.google.com/uc?id=1A3ftF118IcxMn_QONndR-8dPWpf7XzdV'
model_path = './ViTPose/checkpoints/vitpose-h.pth'
if not os.path.exists(model_path):
    print("Downloading ViTPose model...")
    gdown.download(model_url, model_path, fuzzy=True)
# Out:
# Downloading ViTPose model...
# Downloading...
# From (original): https://drive.google.com/uc?id=1A3ftF118IcxMn_QONndR-8dPWpf7XzdV
# From (redirected): https://drive.google.com/uc?id=1A3ftF118IcxMn_QONndR-8dPWpf7XzdV&confirm=t&uuid=e968b6ea-73f4-47ff-8075-665725f32125
# To: /kaggle/working/ViTPose/checkpoints/vitpose-h.pth
# 100%|██████████| 2.55G/2.55G [00:47<00:00, 53.3MB/s]

# %%
import mmcv
import mmengine
import mmdet
import mmpose
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("MMCV version:", mmcv.__version__)
print("MMEngine version:", mmengine.__version__)
print("MMDet version:", mmdet.__version__)
print("MMPose version:", mmpose.__version__)

# Check if model and config exist
print("\nChecking files:")
print("Model exists:", os.path.exists('./ViTPose/checkpoints/vitpose-h.pth'))
print("\nAvailable configs:")
config_dir = './ViTPose/configs'
if os.path.exists(config_dir):
    for root, dirs, files in os.walk(config_dir):
        for file in files:
            if 'vitpose_huge' in file.lower() and file.endswith('.py'):
                print(os.path.join(root, file))
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# MMCV version: 2.1.0
# MMEngine version: 0.10.7
# MMDet version: 3.3.0
# MMPose version: 1.3.2
#
# Checking files:
# Model exists: True
#
# Available configs:
# ./ViTPose/configs/wholebody/2d_kpt_sview_rgb_img/topdown_heatmap/coco-wholebody/ViTPose_huge_wholebody_256x192.py
# ./ViTPose/configs/animal/2d_kpt_sview_rgb_img/topdown_heatmap/apt36k/ViTPose_huge_apt36k_256x192.py
# ./ViTPose/configs/animal/2d_kpt_sview_rgb_img/topdown_heatmap/ap10k/ViTPose_huge_ap10k_256x192.py
# ./ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/mpii/ViTPose_huge_mpii_256x192.py
# ./ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/ViTPose_huge_coco_256x192.py
# ./ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/ViTPose_huge_simple_coco_256x192.py
# ./ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/aic/ViTPose_huge_aic_256x192.py
# ./ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/crowdpose/ViTPose_huge_crowdpose_256x192.py
# ./ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/ochuman/ViTPose_huge_ochuman_256x192.py
# ./ViTPose/configs/hand/2d_kpt_sview_rgb_img/topdown_heatmap/interhand2d/ViTPose_huge_interhand2d_all_256x192.py

# %%
# !pip install -U openmim
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from openmim) (0.4.6)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (2.2.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.7)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (3.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (4.67.1)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2025.1.31)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas->openmim) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas->openmim) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas->openmim) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas->openmim) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas->openmim) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas->openmim) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.10/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.6 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.7 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 27.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.22.4->pandas->openmim) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.22.4->pandas->openmim) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pandas->openmim) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.22.4->pandas->openmim) (2024.2.0)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (44.0.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.22.4->pandas->openmim) (2024.2.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.4 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 21.4 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.9 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 15.8 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 26.4 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.6 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 8.9 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 47.8 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 6.7 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=069aa180ca3baee002f8ed8cbae235ed8cb709947622f7b82673b00d39c2b292
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535316 sha256=1459eb8fdfe349e5a93e41f74cc880dda1f355d1b5d021476ee5467080da44ec
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=d04edae144156377f9193599edeb3cacec8453a07c68e2d582bfcd3b732e3952
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, ordered-set, jmespath, filelock, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.1
#     Uninstalling pytz-2025.1:
#       Successfully uninstalled pytz-2025.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.17.0
#     Uninstalling filelock-3.17.0:
#       Successfully uninstalled filelock-3.17.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.3.1 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.3.1 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# jupyterlab-server 2.27.3 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# pymc 5.19.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# pytensor 2.26.4 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# yfinance 0.2.50 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20

# %%
# !mim download mmpose --config rtmpose-l_8xb256-420e_coco-256x192 --dest .
# Out:
# processing rtmpose-l_8xb256-420e_coco-256x192...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 MiB 18.4 MB/s eta 0:00:0000:0100:01
# Successfully downloaded rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth to /kaggle/working
# Successfully dumped rtmpose-l_8xb256-420e_coco-256x192.py to /kaggle/working

# %%
import os
# Check current directory for downloaded files
print("Files in current directory:")
# !ls *.py  # Look for config files
# !ls *.pth  # Look for model weights
# Out:
# Files in current directory:
# rtmpose-l_8xb256-420e_coco-256x192.py
# rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth

# %%
import mmpose
print("MMPose version:", mmpose.__version__)
print("MMPose installation path:", mmpose.__path__)

# Check for RTMPose configs
def find_rtmpose_configs(base_path):
    """Find RTMPose config files"""
    print("\nSearching for RTMPose configs...")
    for root, dirs, files in os.walk(base_path[0]):
        for file in files:
            if 'rtmpose' in file.lower() and file.endswith('.py'):
                print(os.path.join(root, file))

find_rtmpose_configs(mmpose.__path__)
# Out:
# MMPose version: 1.3.2
# MMPose installation path: ['/usr/local/lib/python3.10/dist-packages/mmpose']
#
# Searching for RTMPose configs...
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/face_2d_keypoint/rtmpose/wflw/rtmpose-m_8xb64-60e_wflw-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/face_2d_keypoint/rtmpose/lapa/rtmpose-m_8xb64-120e_lapa-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/face_2d_keypoint/rtmpose/coco_wholebody_face/rtmpose-m_8xb32-60e_coco-wholebody-face-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/face_2d_keypoint/rtmpose/face6/rtmpose-m_8xb256-120e_face6-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/face_2d_keypoint/rtmpose/face6/rtmpose-t_8xb256-120e_face6-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/face_2d_keypoint/rtmpose/face6/rtmpose-s_8xb256-120e_face6-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/humanart/rtmpose-s_8xb256-420e_humanart-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/humanart/rtmpose-m_8xb256-420e_humanart-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/humanart/rtmpose-t_8xb256-420e_humanart-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/humanart/rtmpose-l_8xb256-420e_humanart-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-m_8xb256-420e_coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-l_8xb256-420e_coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-s_8xb256-420e_aic-coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-m_8xb256-420e_aic-coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-t_8xb256-420e_aic-coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-m_8xb256-420e_aic-coco-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-l_8xb256-420e_aic-coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-s_8xb256-420e_coco-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/coco/rtmpose-l_8xb256-420e_aic-coco-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/crowdpose/rtmpose-m_8xb64-210e_crowdpose-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/mpii/rtmpose-m_8xb64-210e_mpii-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-m_8xb512-700e_body8-halpe26-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-s_8xb256-420e_body8-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-x_8xb256-700e_body8-halpe26-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-m_8xb256-420e_body8-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-l_8xb512-700e_body8-halpe26-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-s_8xb1024-700e_body8-halpe26-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-l_8xb256-420e_body8-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-l_8xb256-420e_body8-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-t_8xb256-420e_body8-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-m_8xb256-420e_body8-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-t_8xb1024-700e_body8-halpe26-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-m_8xb512-700e_body8-halpe26-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/body_2d_keypoint/rtmpose/body8/rtmpose-l_8xb512-700e_body8-halpe26-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/dwpose/ubody/s1_dis/rtmpose_x_dis_l_coco-ubody-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-m_8xb64-270e_coco-ubody-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-t_8xb64-270e_coco-ubody-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-s_8xb64-270e_coco-ubody-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-l_8xb32-270e_coco-ubody-wholebody-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-x_8xb64-270e_coco-ubody-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-l_8xb64-270e_coco-ubody-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/ubody/rtmpose-x_8xb32-270e_coco-ubody-wholebody-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/coco-wholebody/rtmpose-m_8xb64-270e_coco-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/coco-wholebody/rtmpose-l_8xb64-270e_coco-wholebody-256x192.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/coco-wholebody/rtmpose-x_8xb32-270e_coco-wholebody-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/wholebody_2d_keypoint/rtmpose/coco-wholebody/rtmpose-l_8xb32-270e_coco-wholebody-384x288.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/hand_2d_keypoint/rtmpose/coco_wholebody_hand/rtmpose-m_8xb32-210e_coco-wholebody-hand-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/hand_2d_keypoint/rtmpose/hand5/rtmpose-m_8xb256-210e_hand5-256x256.py
# /usr/local/lib/python3.10/dist-packages/mmpose/.mim/configs/animal_2d_keypoint/rtmpose/ap10k/rtmpose-m_8xb64-210e_ap10k-256x256.py

# %%
import cv2
import numpy as np
from mmpose.apis import inference_topdown, init_model
from mmpose.utils import register_all_modules
import matplotlib.pyplot as plt

def visualize_vitpose_steps(image_path, model):
    """Visualize each step of ViTPose processing"""
    
    # 1. Load and preprocess image
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    print("Input Image Shape:", image.shape)
    
    # 2. Get pose estimation results
    bboxes = [[0, 0, image.shape[1], image.shape[0]]]
    results = inference_topdown(model, image, bboxes)
    
    # Extract keypoints from the new format
    # The keypoints are now in pred_instances
    keypoints = results[0].pred_instances.keypoints[0]  # Shape: (17, 2)
    scores = results[0].pred_instances.keypoint_scores[0]  # Shape: (17,)
    
    # Combine keypoints and scores
    keypoints_with_scores = np.concatenate([keypoints, scores[:, None]], axis=1)
    print("\nKeypoints Shape:", keypoints_with_scores.shape)
    print("\nSample Keypoint (Left Shoulder):", keypoints_with_scores[5])
    
    # 3. Visualize keypoints on image
    def draw_keypoints(img, keypoints_with_scores):
        img_copy = img.copy()
        for i, (x, y, conf) in enumerate(keypoints_with_scores):
            if conf > 0.3:  # Only draw high-confidence points
                cv2.circle(img_copy, (int(x), int(y)), 3, (0, 255, 0), -1)
                cv2.putText(img_copy, str(i), (int(x), int(y)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
        return img_copy
    
    keypoint_viz = draw_keypoints(image_rgb, keypoints_with_scores)
    
    # 4. Extract and visualize torso
    def get_torso_crop(img, keypoints_with_scores):
        # Get torso keypoints
        l_shoulder = keypoints_with_scores[5][:2]
        r_shoulder = keypoints_with_scores[6][:2]
        l_hip = keypoints_with_scores[11][:2]
        r_hip = keypoints_with_scores[12][:2]
        
        # Calculate bounds
        top = max(0, int(min(l_shoulder[1], r_shoulder[1])))
        bottom = min(img.shape[0], int(max(l_hip[1], r_hip[1])))
        left = max(0, int(min(l_shoulder[0], l_hip[0])))
        right = min(img.shape[1], int(max(r_shoulder[0], r_hip[0])))
        
        # Add padding
        padding = 5
        top = max(0, top - padding)
        bottom = min(img.shape[0], bottom + padding)
        left = max(0, left - padding)
        right = min(img.shape[1], right + padding)
        
        # Draw torso box
        img_with_box = img.copy()
        cv2.rectangle(img_with_box, (left, top), (right, bottom), (255, 0, 0), 2)
        
        # Crop torso
        torso = img[top:bottom, left:right]
        
        return img_with_box, torso
    
    boxed_image, torso_crop = get_torso_crop(image_rgb, keypoints_with_scores)
    
    # Print keypoint coordinates and confidence
    print("\nKeypoint Coordinates and Confidence:")
    for i, (x, y, conf) in enumerate(keypoints_with_scores):
        if conf > 0.3:  # Only show high-confidence points
            print(f"Keypoint {i}: x={x:.1f}, y={y:.1f}, confidence={conf:.2f}")
    
    # Visualize results
    plt.figure(figsize=(15, 10))
    
    plt.subplot(2, 2, 1)
    plt.title("Original Image")
    plt.imshow(image_rgb)
    
    plt.subplot(2, 2, 2)
    plt.title("Detected Keypoints")
    plt.imshow(keypoint_viz)
    
    plt.subplot(2, 2, 3)
    plt.title("Torso Box")
    plt.imshow(boxed_image)
    
    plt.subplot(2, 2, 4)
    plt.title("Torso Crop")
    plt.imshow(torso_crop)
    
    plt.tight_layout()
    plt.show()
    
    return {
        'original': image_rgb,
        'keypoints': keypoints_with_scores,
        'keypoint_viz': keypoint_viz,
        'boxed': boxed_image,
        'torso': torso_crop
    }

# Usage
register_all_modules()
config = 'rtmpose-l_8xb256-420e_coco-256x192.py'
checkpoint = 'rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth'
model = init_model(config, checkpoint, device='cpu')

# Process a single image
image_path = '/kaggle/input/football-crops/frame_000210_conf_0.83_players_002_318_469.jpg'
results = visualize_vitpose_steps(image_path, model)
# Out:
# Loads checkpoint by local backend from path: rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth
# Input Image Shape: (136, 72, 3)
# /usr/local/lib/python3.10/dist-packages/mmengine/runner/checkpoint.py:347: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=map_location)
# /usr/local/lib/python3.10/dist-packages/mmdet/models/layers/se_layer.py:158: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /usr/local/lib/python3.10/dist-packages/mmdet/models/backbones/csp_darknet.py:118: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# Keypoints Shape: (17, 3)
#
# Sample Keypoint (Left Shoulder): [27.367188   33.80078     0.74833965]
#
# Keypoint Coordinates and Confidence:
# Keypoint 0: x=37.7, y=20.5, confidence=0.45
# Keypoint 1: x=33.0, y=19.2, confidence=0.61
# Keypoint 2: x=42.3, y=19.2, confidence=0.54
# Keypoint 3: x=32.3, y=20.9, confidence=0.87
# Keypoint 4: x=43.0, y=20.9, confidence=0.85
# Keypoint 5: x=27.4, y=33.8, confidence=0.75
# Keypoint 6: x=49.9, y=33.8, confidence=0.81
# Keypoint 7: x=14.8, y=40.8, confidence=0.64
# Keypoint 8: x=57.6, y=50.4, confidence=0.76
# Keypoint 9: x=7.1, y=41.4, confidence=0.60
# Keypoint 10: x=62.6, y=64.7, confidence=0.76
# Keypoint 11: x=35.7, y=66.3, confidence=0.70
# Keypoint 12: x=48.9, y=65.0, confidence=0.73
# Keypoint 13: x=44.3, y=91.6, confidence=0.75
# Keypoint 14: x=44.6, y=87.6, confidence=0.69
# Keypoint 15: x=51.9, y=117.1, confidence=0.70
# Keypoint 16: x=38.3, y=105.5, confidence=0.59

# %%
from mmpose.apis import inference_topdown
from mmpose.apis import init_model
from mmpose.utils import register_all_modules
import cv2
import numpy as np

# Register all modules (This is important!)
register_all_modules()

def test_mmpose():
    # Model loading
    config = 'rtmpose-l_8xb256-420e_coco-256x192.py'  # Use the config we downloaded
    checkpoint = 'rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth'  # Use the checkpoint we downloaded
    model = init_model(config, checkpoint, device='cpu')
    
    # Load an image
    img = cv2.imread('/kaggle/input/football-crops/frame_000210_conf_0.83_players_002_318_469.jpg')
    
    # Single instance detection
    bboxes = [[0, 0, img.shape[1], img.shape[0]]]  # Full image bbox
    
    print("Model:", type(model))
    print("Image shape:", img.shape)
    print("Bboxes:", bboxes)
    
    # Try inference
    try:
        results = inference_topdown(model, img, bboxes)
        print("Results:", results)
    except Exception as e:
        print("Error:", e)
        print("Model config:", model.cfg)

test_mmpose()
# Out:
# Loads checkpoint by local backend from path: rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth
# Model: <class 'mmpose.models.pose_estimators.topdown.TopdownPoseEstimator'>
# Image shape: (136, 72, 3)
# Bboxes: [[0, 0, 72, 136]]
# Results: [<PoseDataSample(
#
#     META INFORMATION
#     input_scale: array([127.5, 170. ])
#     flip_indices: [0, 2, 1, 4, 3, 6, 5, 8, 7, 10, 9, 12, 11, 14, 13, 16, 15]
#     img_path: None
#     dataset_name: 'coco'
#     img_shape: (136, 72)
#     pad_shape: (256, 192)
#     input_center: array([36., 68.])
#     input_size: (192, 256)
#     ori_shape: (136, 72)
#     batch_input_shape: (256, 192)
#
#     DATA FIELDS
#     gt_instance_labels: <InstanceData(
#
#             META INFORMATION
#
#             DATA FIELDS
#         ) at 0x7c71fa9c3670>
#     pred_instances: <InstanceData(
#
#             META INFORMATION
#
#             DATA FIELDS
#             bboxes: array([[  0,   0,  72, 136]])
#             keypoint_scores: array([[0.45005044, 0.60547924, 0.54452515, 0.8690461 , 0.85258067,
#                         0.74833965, 0.8056432 , 0.63614476, 0.7617443 , 0.59674215,
#                         0.7569117 , 0.70451117, 0.73064816, 0.7468518 , 0.68950534,
#                         0.7026236 , 0.5892004 ]], dtype=float32)
#             keypoints: array([[[ 37.660156 ,  20.519531 ],
#                         [ 33.01172  ,  19.191406 ],
#                         [ 42.308594 ,  19.191406 ],
#                         [ 32.347656 ,  20.851562 ],
#                         [ 42.972656 ,  20.851562 ],
#                         [ 27.367188 ,  33.80078  ],
#                         [ 49.945312 ,  33.80078  ],
#                         [ 14.75     ,  40.773438 ],
#                         [ 57.58203  ,  50.402344 ],
#                         [  7.1132812,  41.4375   ],
#                         [ 62.5625   ,  64.67969  ],
#                         [ 35.66797  ,  66.33984  ],
#                         [ 48.94922  ,  65.01172  ],
#                         [ 44.30078  ,  91.57422  ],
#                         [ 44.632812 ,  87.58984  ],
#                         [ 51.9375   , 117.140625 ],
#                         [ 38.32422  , 105.51953  ]]], dtype=float32)
#             keypoints_visible: array([[0.45005044, 0.60547924, 0.54452515, 0.8690461 , 0.85258067,
#                         0.74833965, 0.8056432 , 0.63614476, 0.7617443 , 0.59674215,
#                         0.7569117 , 0.70451117, 0.73064816, 0.7468518 , 0.68950534,
#                         0.7026236 , 0.5892004 ]], dtype=float32)
#             bbox_scores: array([1.], dtype=float32)
#         ) at 0x7c71fa9c1fc0>
#     gt_instances: <InstanceData(
#
#             META INFORMATION
#
#             DATA FIELDS
#             bbox_scales: array([[127.5, 170. ]])
#             bboxes: array([[  0,   0,  72, 136]])
#             keypoints_visible: array([[[1.]]])
#             bbox_scores: array([1.], dtype=float32)
#         ) at 0x7c71fa9c3790>
# ) at 0x7c71fa9c3820>]

# %%
import os
import cv2
import numpy as np
from mmpose.apis import inference_topdown, init_model
from mmpose.utils import register_all_modules
import matplotlib.pyplot as plt

def create_output_directories():
    """Create organized directory structure for outputs"""
    directories = [
        'output',
        'output/original_with_keypoints',
        'output/torso_crops_original',
        'output/torso_crops_processed'
    ]
    
    for dir_path in directories:
        os.makedirs(dir_path, exist_ok=True)
        print(f"Created directory: {dir_path}")

def process_single_image(model, image_path):
    """Process a single image through ViTPose pipeline"""
    # Read image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Could not read image: {image_path}")
        return None
    
    # Get filename without extension
    base_name = os.path.basename(image_path).split('.')[0]
    
    try:
        # Run pose estimation
        results = inference_topdown(model, img, [[0, 0, img.shape[1], img.shape[0]]])
        
        # Visualize keypoints on original image
        vis_img = img.copy()
        keypoints = results[0].pred_instances.keypoints[0]
        
        # Draw keypoints
        keypoint_names = {
            5: ('Left Shoulder', (0, 0, 255)),    # Red
            6: ('Right Shoulder', (0, 255, 0)),   # Green
            11: ('Left Hip', (255, 0, 0)),        # Blue
            12: ('Right Hip', (255, 255, 0))      # Cyan
        }
        
        for idx, (name, color) in keypoint_names.items():
            x, y = map(int, keypoints[idx][:2])
            cv2.circle(vis_img, (x, y), 3, color, -1)
            cv2.putText(vis_img, name, (x-10, y-10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.3, color, 1)
        
        # Save keypoint visualization
        keypoint_path = f'output/original_with_keypoints/{base_name}_keypoints.jpg'
        cv2.imwrite(keypoint_path, vis_img)
        
        # Extract and save torso crops
        torso_original, torso_processed = extract_torso_crops(img, results)
        
        if torso_original is not None:
            # Save original crop
            crop_path = f'output/torso_crops_original/{base_name}_torso.jpg'
            cv2.imwrite(crop_path, torso_original)
            
            # Save processed crop
            processed_path = f'output/torso_crops_processed/{base_name}_torso_processed.jpg'
            cv2.imwrite(processed_path, torso_processed)
            
        return True
        
    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        return False

def extract_torso_crops(img, results):
    """Extract both original and processed torso crops"""
    # Get keypoints
    keypoints = results[0].pred_instances.keypoints[0]
    
    # Extract relevant keypoints
    left_shoulder = keypoints[5][:2].astype(int)
    right_shoulder = keypoints[6][:2].astype(int)
    left_hip = keypoints[11][:2].astype(int)
    right_hip = keypoints[12][:2].astype(int)
    
    # Calculate bounding box with padding
    padding = 5
    x1 = max(0, int(min(left_shoulder[0], left_hip[0])) - padding)
    y1 = max(0, int(min(left_shoulder[1], right_shoulder[1])) - padding)
    x2 = min(img.shape[1], int(max(right_shoulder[0], right_hip[0])) + padding)
    y2 = min(img.shape[0], int(max(left_hip[1], right_hip[1])) + padding)
    
    # Get original crop
    torso_original = img[y1:y2, x1:x2]
    
    # Create processed crop
    torso_processed = torso_original.copy()
    
    # Apply preprocessing
    # 1. Resize
    torso_processed = cv2.resize(torso_processed, (0,0), fx=2, fy=2)
    
    # 2. Sharpen
    kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    torso_processed = cv2.filter2D(torso_processed, -1, kernel)
    
    # 3. Enhance contrast
    lab = cv2.cvtColor(torso_processed, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl,a,b))
    torso_processed = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    
    return torso_original, torso_processed

def process_all_legible_crops():
    """Process all images in the legible_crops directory"""
    # Create output directories
    create_output_directories()
    
    # Initialize model
    print("Initializing ViTPose model...")
    model = init_model('rtmpose-l_8xb256-420e_coco-256x192.py', 
                      'rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth', 
                      device='cpu')
    
    # Process each image
    legible_crops_dir = '/kaggle/input/football-crops/'
    total_images = 0
    successful_processes = 0
    
    for filename in os.listdir(legible_crops_dir):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            total_images += 1
            image_path = os.path.join(legible_crops_dir, filename)
            print(f"\nProcessing {filename}...")
            
            if process_single_image(model, image_path):
                successful_processes += 1
    
    print(f"\nProcessing complete!")
    print(f"Total images processed: {total_images}")
    print(f"Successful processes: {successful_processes}")
    print(f"Failed processes: {total_images - successful_processes}")

# Run the processing
register_all_modules()
process_all_legible_crops()
# Out:
# Created directory: output
# Created directory: output/original_with_keypoints
# Created directory: output/torso_crops_original
# Created directory: output/torso_crops_processed
# Initializing ViTPose model...
# Loads checkpoint by local backend from path: rtmpose-l_simcc-coco_pt-aic-coco_420e-256x192-1352a4d2_20230127.pth
#
# Processing frame_000810_conf_0.52_players_004_914_203.jpg...
#
# Processing frame_001950_conf_0.86_players_001_1126_714.jpg...
#
# Processing frame_000270_conf_0.83_players_000_1076_646.jpg...
#
# Processing frame_000330_conf_0.85_players_000_1265_616.jpg...
#
# Processing frame_001770_conf_0.84_players_001_1284_950.jpg...
#
# Processing frame_000180_conf_0.81_players_001_549_451.jpg...
#
# Processing frame_000360_conf_0.83_players_001_1098_243.jpg...
#
# Processing frame_001470_conf_0.81_players_005_683_341.jpg...
#
# Processing frame_000390_conf_0.90_players_000_1095_234.jpg...
#
# Processing frame_001230_conf_0.83_players_002_670_420.jpg...
#
# Processing frame_003450_conf_0.82_players_003_275_741.jpg...
#
# Processing frame_001050_conf_0.79_players_001_791_605.jpg...
#
# Processing frame_002370_conf_0.85_players_001_1205_742.jpg...
#
# Processing frame_002010_conf_0.87_players_000_857_682.jpg...
#
# Processing frame_002160_conf_0.85_players_001_1156_512.jpg...
#
# Processing frame_003870_conf_0.79_players_003_580_375.jpg...
#
# Processing frame_000300_conf_0.84_players_000_912_526.jpg...
#
# Processing frame_001590_conf_0.84_players_000_1340_568.jpg...
#
# Processing frame_000210_conf_0.83_players_002_318_469.jpg...
#
# Processing frame_003540_conf_0.82_players_003_1150_572.jpg...
#
# Processing frame_003840_conf_0.77_players_004_74_495.jpg...
#
# Processing frame_000420_conf_0.89_players_000_1013_155.jpg...
#
# Processing complete!
# Total images processed: 22
# Successful processes: 22
# Failed processes: 0

# %%
# !zip -r folder_name.zip /kaggle/working/output
# Out:
#   adding: kaggle/working/output/ (stored 0%)
#   adding: kaggle/working/output/torso_crops_processed/ (stored 0%)
#   adding: kaggle/working/output/torso_crops_processed/frame_003540_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_002370_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000180_conf_0_torso_processed.jpg (deflated 4%)
#   adding: kaggle/working/output/torso_crops_processed/frame_001050_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000420_conf_0_torso_processed.jpg (deflated 0%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000270_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_001230_conf_0_torso_processed.jpg (deflated 4%)
#   adding: kaggle/working/output/torso_crops_processed/frame_001770_conf_0_torso_processed.jpg (deflated 2%)
#   adding: kaggle/working/output/torso_crops_processed/frame_003870_conf_0_torso_processed.jpg (deflated 4%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000300_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_002010_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000810_conf_0_torso_processed.jpg (deflated 0%)
#   adding: kaggle/working/output/torso_crops_processed/frame_002160_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_001590_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_003450_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_001950_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000390_conf_0_torso_processed.jpg (deflated 1%)
#   adding: kaggle/working/output/torso_crops_processed/frame_003840_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000210_conf_0_torso_processed.jpg (deflated 4%)
#   adding: kaggle/working/output/torso_crops_processed/frame_001470_conf_0_torso_processed.jpg (deflated 4%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000330_conf_0_torso_processed.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_processed/frame_000360_conf_0_torso_processed.jpg (deflated 0%)
#   adding: kaggle/working/output/original_with_keypoints/ (stored 0%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000420_conf_0_keypoints.jpg (deflated 0%)
#   adding: kaggle/working/output/original_with_keypoints/frame_003840_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000360_conf_0_keypoints.jpg (deflated 1%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000180_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_001470_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_001230_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000810_conf_0_keypoints.jpg (deflated 0%)
#   adding: kaggle/working/output/original_with_keypoints/frame_002370_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_001950_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_001770_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000210_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_003450_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000390_conf_0_keypoints.jpg (deflated 0%)
#   adding: kaggle/working/output/original_with_keypoints/frame_001050_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_001590_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000330_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_003540_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_003870_conf_0_keypoints.jpg (deflated 3%)
#   adding: kaggle/working/output/original_with_keypoints/frame_002160_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_002010_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000270_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/original_with_keypoints/frame_000300_conf_0_keypoints.jpg (deflated 2%)
#   adding: kaggle/working/output/torso_crops_original/ (stored 0%)
#   adding: kaggle/working/output/torso_crops_original/frame_003840_conf_0_torso.jpg (deflated 10%)
#   adding: kaggle/working/output/torso_crops_original/frame_002370_conf_0_torso.jpg (deflated 10%)
#   adding: kaggle/working/output/torso_crops_original/frame_000270_conf_0_torso.jpg (deflated 9%)
#   adding: kaggle/working/output/torso_crops_original/frame_000210_conf_0_torso.jpg (deflated 12%)
#   adding: kaggle/working/output/torso_crops_original/frame_000360_conf_0_torso.jpg (deflated 2%)
#   adding: kaggle/working/output/torso_crops_original/frame_001050_conf_0_torso.jpg (deflated 10%)
#   adding: kaggle/working/output/torso_crops_original/frame_001950_conf_0_torso.jpg (deflated 9%)
#   adding: kaggle/working/output/torso_crops_original/frame_000180_conf_0_torso.jpg (deflated 12%)
#   adding: kaggle/working/output/torso_crops_original/frame_001230_conf_0_torso.jpg (deflated 12%)
#   adding: kaggle/working/output/torso_crops_original/frame_002160_conf_0_torso.jpg (deflated 9%)
#   adding: kaggle/working/output/torso_crops_original/frame_000300_conf_0_torso.jpg (deflated 11%)
#   adding: kaggle/working/output/torso_crops_original/frame_003870_conf_0_torso.jpg (deflated 13%)
#   adding: kaggle/working/output/torso_crops_original/frame_000420_conf_0_torso.jpg (deflated 1%)
#   adding: kaggle/working/output/torso_crops_original/frame_001590_conf_0_torso.jpg (deflated 11%)
#   adding: kaggle/working/output/torso_crops_original/frame_002010_conf_0_torso.jpg (deflated 9%)
#   adding: kaggle/working/output/torso_crops_original/frame_000330_conf_0_torso.jpg (deflated 11%)
#   adding: kaggle/working/output/torso_crops_original/frame_000390_conf_0_torso.jpg (deflated 3%)
#   adding: kaggle/working/output/torso_crops_original/frame_000810_conf_0_torso.jpg (deflated 1%)
#   adding: kaggle/working/output/torso_crops_original/frame_003450_conf_0_torso.jpg (deflated 9%)
#   adding: kaggle/working/output/torso_crops_original/frame_003540_conf_0_torso.jpg (deflated 9%)
#   adding: kaggle/working/output/torso_crops_original/frame_001470_conf_0_torso.jpg (deflated 15%)
#   adding: kaggle/working/output/torso_crops_original/frame_001770_conf_0_torso.jpg (deflated 7%)
